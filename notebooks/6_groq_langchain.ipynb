# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model = "openai/gpt-oss-20b")

# %%
res = llm.invoke(

 "Please explain me the Dependence Injection in .Net with an example in C# and also provide me the code for the same."
)
print(res.content)
# Out:
# ## 1.  What is Dependency Injection (DI)?
#
# | Term | Meaning |
# |------|---------|
# | **Dependency** | A class that needs another class to do its job (e.g., a `NotificationService` that needs an `IEmailSender`). |
# | **Injection** | The act of providing that dependency to the class, usually through a constructor, a property, or a method. |
# | **Inversion of Control (IoC)** | The principle that the *control* of creating and wiring objects is *inverted* from the class itself to an external component (the DI container). |
#
# DI is a *pattern* that lets you:
#
# * **Decouple** classes (they no longer create or look up their own dependencies).
# * **Swap implementations** (e.g., use a mock email sender in tests, a real SMTP sender in production).
# * **Improve testability** (you can inject fake objects).
# * **Manage object lifetimes** (singleton, scoped, transient).
#
# ...
