# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("../data/demotestfile.txt")
text = loader.load()
len(text)
oneDoc= text[0]
print(oneDoc.page_content)
# Out:
# Hi Vivek,
#
# As discussed, please find below my planned roadmap for Java and Spring Boot. Since I already have experience with .NET and backend development, I have kept the basic Java concepts consolidated into the first day and allocated more time to the Java/Spring-specific concepts and hands-on implementation.
#
# | Day       | Planned Learning / Activity                                                                                                                   | Expected Outcome                                              |
# | --------- | --------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------- |
# | **Day 1** | **Core Java Basics:** Java syntax, OOP concepts, Exception Handling, Collections, Generics and Multithreading                                 | Get familiar with Java and map existing .NET concepts to Java |
# ...

# %%
# Out:
# [Document(metadata={'source': '../data/demotestfile.txt'}, page_content='Hi Vivek,\n\nAs discussed, please find below my planned roadmap for Java and Spring Boot. Since I already have experience with .NET and backend development, I have kept the basic Java concepts consolidated into the first day and allocated more time to the Java/Spring-specific concepts and hands-on implementation.\n\n| Day       | Planned Learning / Activity                                                                                                                   | Expected Outcome                                              |\n| --------- | --------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------- |\n| **Day 1** | **Core Java Basics:** Java syntax, OOP concepts, Exception Handling, Collections, Generics and Multithreading                                 | Get
# ...

# %% [markdown]
# PDF Document loader

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("../data/Hampta_Pass.pdf")
docs = loader.load()
len(docs)
# Out:
# incorrect startxref pointer(1)
# parsing for Object Streams
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# Error -3 while decompressing data: incorrect header check
# ...

# %% [markdown]
# WEB PAGE LOADER

# %%
from langchain_community.document_loaders import WebBaseLoader
load = WebBaseLoader(web_path="https://techsimplus.com/")
docs = load.load()

# %%
docs[0].page_content
# Out:
# "TechSimPlus : Transforming Careers through Cutting-Edge Tech TrainingInternshipVector 1.OEventsAbout UsCertificateConnect UsLoginHomeEventsAbout UsInstitute SolutionConnect UsLoginJoin Vector 1.OCopyright 2026 © TechSimPlus - The Symbol of Expertise.Designed by\xa0 Prateek MishraCode. Build. Get Hired.Explore our courses12k+Trained Students200+Institute Trainings500+Projects11 LPA+Avarage CTCWatch intro videoOur students got a placementThese are students who joined Techsimplus to expand their careers and were placed on high-tech companies.Ashutosh MajhiAkshat JainAjay Kumar MandalAkash HarioudhAnuj PandeyAman ShahAnandita KumariAnkit LambaAnshu KumariAnuprash GuptaArun PariharBhagyashree GohiyaBharat TiwariManish Singh Naresh Choudhary Nidhi Khandelwal Nipun Gupta Pratiksha DubeyRaghav KabraVidhi bhardwajPrince KhatriTarun DangiTanay SisodiyaSee what our Student's SayDiscover what our students are saying about their transformative journey with us!Nipun GuptaLearning with TechSimPlus
# ...

# %% [markdown]
# WIKIPEDIA LOADER

# %%
from langchain_community.document_loaders import WikipediaLoader
loader = WikipediaLoader(query = "Gen AI", load_max_docs=2)
docs = loader.load()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\ysingh\OneDrive - Insight\Desktop\GenAI\env\Lib\site-packages\requests\models.py:1116, in Response.json(self, **kwargs)
#    1115 try:
# -> 1116     return complexjson.loads(self.text, **kwargs)
#    1117 except JSONDecodeError as e:
#    1118     # Catch JSON-related errors and raise as requests.JSONDecodeError
#    1119     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File C:\Users\ysingh\AppData\Local\Programs\Python\Python314\Lib\json\__init__.py:352, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     349 if (cls is None and object_hook is None and
#     350         parse_int is None and parse_float is None and
#     351         parse_constant is None and object_pairs_hook is None and not kw):
# ...
